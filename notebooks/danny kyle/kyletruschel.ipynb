# %% [markdown]
# ## Introduction
# Our group decided to analyze wine data from 2019 to search for the most quality wines available at that time.
# In particular, we wanted to find out the most valuable wine with context based on price and score.
# Data was compiled from the tidytuesday github, who provided a large amount of wine related data from 2019.

# %% [markdown]
# ---
# title: "Wine Ratings 2019"
# author: "Kyle and Danny"
# date: today
# format:
#     html:
#         code-fold: true
#         theme: lux
# ---

# %% [markdown]
# ## Simple data exploration
# The first critera we examined was the top 25 best winerys.
# The best critera was examined based on points.

# %%
#| label: fig-label-to-make-reference
#| fig-cap: "Short explanation"

import pandas as pd
# Load the dataset
data = pd.read_csv("winemag-data-130k-v2.csv")

# Create a filtered DataFrame with only specific columns
data_winerys = data[['title', 'winery', 'country','points']]
top_25_wines = data_winerys.nlargest(25, 'points').reset_index(drop=True)

# Make index start from 1 instead of 0
top_25_wines.index = range(1, 26)
top_25_wines
# Out:
#                                                 title  \
# 1   Chambers Rosewood Vineyards NV Rare Muscat (Ru...
# 2   Avignonesi 1995 Occhio di Pernice  (Vin Santo ...
# 3                         Krug 2002 Brut  (Champagne)
# 4   Tenuta dell'Ornellaia 2007 Masseto Merlot (Tos...
# 5       Casa Ferreirinha 2008 Barca-Velha Red (Douro)
# 6   Biondi Santi 2010 Riserva  (Brunello di Montal...
# 7     Cardinale 2006 Cabernet Sauvignon (Napa Valley)
# 8          Château Léoville Barton 2010  Saint-Julien
# 9   Louis Roederer 2008 Cristal Vintage Brut  (Cha...
# 10  Salon 2006 Le Mesnil Blanc de Blancs Brut Char...
# 11           Château Lafite Rothschild 2010  Pauillac
# 12  Casanova di Neri 2007 Cerretalto  (Brunello di...
# 13           Château Cheval Blanc 2010  Saint-Émilion
# 14      Château Léoville Las Cases 2010  Saint-Julien
# 15  Charles Smith 2006 Royal City Syrah (Columbia ...
# 16      Quinta do Noval 2011 Nacional Vintage  (Port)
# ...

# %% [markdown]
# ## Your new shiny data visualization
# Using a simple bar chart that displays the best winerys by country, we have concluded that based on this dataset, France scored in first for the top winerys, followed by a tie between the US and Italy.

# %%
#| output: false
#| echo: false

# Install matplotlib if not already installed
import sys
# !{sys.executable} -m pip install matplotlib

# %%
import matplotlib.pyplot as plt

# Data
countries = ['Australia', 'Italy', 'France', 'Portugal', 'US']
wine_counts = [1, 6, 9, 2, 6]

# Wine-themed colors
wine_color = '#722F37'  # a rich red wine color
bg_color = '#F9F5F0'    # off-white, like a wine label

# Create bar chart
plt.figure(figsize=(10, 6), facecolor=bg_color)
bars = plt.bar(countries, wine_counts, color=wine_color)

# Add title and labels
plt.title('Winery Rating by Country', fontsize=16, color=wine_color)
plt.xlabel('Country', fontsize=12)
plt.ylabel('Points', fontsize=12)

# Annotate bars with values
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.2, yval, 
             ha='center', va='bottom', fontsize=10, color=wine_color)

# Set background color for plot area
plt.gca().set_facecolor(bg_color)

# Remove top and right borders
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Conclusion
# We hope to show that the data given in 2019 will identify the most valuable wine selections.
